# %%
import pandas as pd
import seaborn as sns

# %%
dados = sns.load_dataset('tips')
#print(dados.head(10))
dados.head()#O mais adequado para uma analise exploratória rápida.
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#dados["time"]
dados.head()
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: category
# Categories (2, object): ['Lunch', 'Dinner']

# %%
dados[dados["time"] == "Lunch"]
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 77        27.20  4.00    Male     No  Thur  Lunch     4
# 78        22.76  3.00    Male     No  Thur  Lunch     2
# 79        17.29  2.71    Male     No  Thur  Lunch     2
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2
# 81        16.66  3.40    Male     No  Thur  Lunch     2
# ..          ...   ...     ...    ...   ...    ...   ...
# 222        8.58  1.92    Male    Yes   Fri  Lunch     1
# 223       15.98  3.00  Female     No   Fri  Lunch     3
# 224       13.42  1.58    Male    Yes   Fri  Lunch     2
# 225       16.27  2.50  Female    Yes   Fri  Lunch     2
# 226       10.09  2.00  Female    Yes   Fri  Lunch     2
#
# [68 rows x 7 columns]

# %%
nova_lista = dados[(dados["time"] == "Lunch") & (dados["sex"] == "Male") & (dados["smoker"] == "No")]

# %%
nova_lista.head()
# Out:
#     total_bill   tip   sex smoker   day   time  size
# 77       27.20  4.00  Male     No  Thur  Lunch     4
# 78       22.76  3.00  Male     No  Thur  Lunch     2
# 79       17.29  2.71  Male     No  Thur  Lunch     2
# 81       16.66  3.40  Male     No  Thur  Lunch     2
# 84       15.98  2.03  Male     No  Thur  Lunch     2

# %%
#nova_lista["sex"] = "Gay"
nova_lista.loc[:, "sex"] = "Gay"

# %%
nova_lista.head()
# Out:
#     total_bill   tip  sex smoker   day   time  size
# 77       27.20  4.00  Gay     No  Thur  Lunch     4
# 78       22.76  3.00  Gay     No  Thur  Lunch     2
# 79       17.29  2.71  Gay     No  Thur  Lunch     2
# 81       16.66  3.40  Gay     No  Thur  Lunch     2
# 84       15.98  2.03  Gay     No  Thur  Lunch     2

# %%
dados.loc[dados[(dados["time"] == "Lunch") & (dados["sex"] == "Male") & (dados["smoker"] == "No")]] = "Gay"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dados.loc[dados[(dados["time"] == "Lunch") & (dados["sex"] == "Male") & (dados["smoker"] == "No")]] = "Gay"
#
# File ~/anaconda3/envs/AmbienteDSA/lib/python3.12/site-packages/pandas/core/indexing.py:907, in _LocationIndexer.__setitem__(self, key, value)
#     905     maybe_callable = com.apply_if_callable(key, self.obj)
#     906     key = self._check_deprecated_callable_usage(key, maybe_callable)
# --> 907 indexer = self._get_setitem_indexer(key)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/anaconda3/envs/AmbienteDSA/lib/python3.12/site-packages/pandas/core/indexing.py:780, in _LocationIndexer._get_setitem_indexer(self, key)
#     776 if isinstance(key, range):
#     777     # GH#45479 test_loc_setitem_range_key
# ...

# %%
dados.head
# Out:
# <bound method NDFrame.head of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
dados["time"]
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: category
# Categories (2, object): ['Lunch', 'Dinner']

# %%
dados["time"]
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: category
# Categories (2, object): ['Lunch', 'Dinner']

# %%
#dados.loc[dados[(dados["time"] == "Lunch") & (dados["sex"] == "Male") & (dados["smoker"] == "No")]] = "Gay"
#dados.loc[(dados["time"] == "Lunch") & (dados["sex"] == "Male") & (dados["smoker"] == "No"), "sex"] = "Gay"
# Corrigindo o uso de .loc para modificar a coluna 'sex' onde as condições são satisfeitas
dados.loc[(dados["time"] == "Lunch") & (dados["sex"] == "Male") & (dados["smoker"] == "No"), 'sex'] = "Gay"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 #dados.loc[dados[(dados["time"] == "Lunch") & (dados["sex"] == "Male") & (dados["smoker"] == "No")]] = "Gay"
#       2 #dados.loc[(dados["time"] == "Lunch") & (dados["sex"] == "Male") & (dados["smoker"] == "No"), "sex"] = "Gay"
#       3 # Corrigindo o uso de .loc para modificar a coluna 'sex' onde as condições são satisfeitas
# ----> 4 dados.loc[(dados["time"] == "Lunch") & (dados["sex"] == "Male") & (dados["smoker"] == "No"), 'sex'] = "Gay"
#
# File ~/anaconda3/envs/AmbienteDSA/lib/python3.12/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# ...
